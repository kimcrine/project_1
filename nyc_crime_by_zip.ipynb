# %%
# Import dependencies:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import scipy.stats as st

# Read in crime csv:
crime_file = "nypd_crime.csv"
crime_df = pd.read_csv(crime_file)

# Take a look:
crime_df.head(10)
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   942919936           77       NaN   06/29/2020     18:10:00          NaN
# 1   444710066           60       NaN   06/20/2020     13:52:00          NaN
# 2   121536456           47       NaN   06/12/2020     23:00:00          NaN
# 3   314830920           75       NaN   06/05/2020     20:20:00          NaN
# 4   173858725          101       NaN   06/05/2020     19:20:00          NaN
# 5   859565694           48       NaN   06/05/2020     00:07:00          NaN
# 6   756614793           75       NaN   05/28/2020     23:53:00          NaN
# 7   237202728           75  BROOKLYN   05/16/2020     17:56:00          NaN
# 8   517518318           77       NaN   05/05/2020     22:31:00          NaN
# 9   354783980           73       NaN   04/19/2020     14:50:00          NaN
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD          HADEVELOPT  HOUSING_PSA  ...  \
# ...

# %%
#Cleaning data; remove unneeded columns, rename to words:

cleaning_df = pd.DataFrame(crime_df[["ADDR_PCT_CD", "CMPLNT_NUM", "BORO_NM", "LAW_CAT_CD"]])
cleaning_df = cleaning_df.rename(columns = {"ADDR_PCT_CD": "Precinct", "CMPLNT_NUM": "Complaint Number", "BORO_NM": "Borough", 
                                           "LAW_CAT_CD": "Category",})
cleaning_df.head(10)
# Out:
#    Precinct  Complaint Number   Borough Category
# 0        77         942919936       NaN   FELONY
# 1        60         444710066       NaN   FELONY
# 2        47         121536456       NaN   FELONY
# 3        75         314830920       NaN   FELONY
# 4       101         173858725       NaN   FELONY
# 5        48         859565694       NaN   FELONY
# 6        75         756614793       NaN   FELONY
# 7        75         237202728  BROOKLYN   FELONY
# 8        77         517518318       NaN   FELONY
# 9        73         354783980       NaN   FELONY

# %%
# Loop through the crime data and translate the jurisdiction number into a zip code, based those listed on 
# NYPD's website for the 77 jurisdictions:

zip_codes = []

for value in cleaning_df["Precinct"]:
    if value == 1:
        zip = 10013
    if value == 5:
        zip = 10013
    if value == 6:
        zip = 10014
    if value == 7:
        zip = 10002
    if value == 9:
        zip = 10003
    if value == 10:
        zip = 10011
    if value == 13:
        zip = 10010
    if value == 14:
        zip = 10001
    if value == 17:
        zip = 10022
    if value == 18:
        zip = 10019
    if value == 19:
        zip = 10065
    if value == 20:
        zip = 10024
    if value == 22:
        zip = 10024
    if value == 23:
        zip = 10029
    if value == 24:
        zip = 10025
    if value == 25:
        zip = 10035
    if value == 26:
        zip = 10027
    if value == 28:
        zip = 10027
    if value == 30:
        zip = 10031
    if value == 32:
        zip = 10030
    if value == 33:
        zip = 10032
    if value == 34:
        zip = 10033
    if value == 40:
        zip = 10454
    if value == 41:
        zip = 10459
    if value == 42:
        zip = 10451
    if value == 43:
        zip = 10473
    if value == 44:
        zip = 10452
    if value == 45:
        zip = 10465
    if value == 46:
        zip = 10457
    if value == 47:
        zip = 10466
    if value == 48:
        zip = 10457
    if value == 49:
        zip = 10461
    if value == 50:
        zip = 10463
    if value == 52:
        zip = 10467
    if value == 60:
        zip = 11224
    if value == 61:
        zip = 11223
    if value == 62:
        zip = 11214
    if value == 63:
        zip = 11210
    if value == 66:
        zip = 11204
    if value == 67:
        zip = 11226
    if value == 68:
        zip = 11236
    if value == 69:
        zip = 11236
    if value == 70:
        zip = 11230
    if value == 71:
        zip = 11225
    if value == 72:
        zip = 11232
    if value == 73:
        zip = 11212
    if value == 75:
        zip = 11208
    if value == 76:
        zip = 11231
    if value == 77:
        zip = 11213
    if value == 78:
        zip = 11217
    if value == 79:
        zip = 11216
    if value == 81:
        zip = 11221
    if value == 83:
        zip = 11237
    if value == 84:
        zip = 11201
    if value == 88:
        zip = 11205
    if value == 90:
        zip = 11211
    if value == 94:
        zip = 11222
    if value == 100:
        zip = 11693
    if value == 101:
        zip = 11691
    if value == 102:
        zip = 11418
    if value == 103:
        zip = 11432
    if value == 104:
        zip = 11385
    if value == 105:
        zip = 11428
    if value == 106:
        zip = 11417
    if value == 107:
        zip = 11365
    if value == 108:
        zip = 11101
    if value == 109:
        zip = 11354
    if value == 110:
        zip = 11373
    if value == 111:
        zip = 11361
    if value == 112:
        zip = 11375
    if value == 113:
        zip = 11434
    if value == 114:
        zip = 11103
    if value == 115:
        zip = 11372
    if value == 120:
        zip = 10301
    if value == 121:
        zip = 10314
    if value == 122:
        zip = 10306
    if value == 123:
        zip = 10307
    zip_codes.append(zip)

# %%
len(zip_codes)
# Out:
# 196853

# %%
cleaning_df["Zip"] = zip_codes

# %%
cleaning_df.head(10)
# Out:
#    Precinct  Complaint Number   Borough Category    Zip
# 0        77         942919936       NaN   FELONY  11213
# 1        60         444710066       NaN   FELONY  11224
# 2        47         121536456       NaN   FELONY  10466
# 3        75         314830920       NaN   FELONY  11208
# 4       101         173858725       NaN   FELONY  11691
# 5        48         859565694       NaN   FELONY  10457
# 6        75         756614793       NaN   FELONY  11208
# 7        75         237202728  BROOKLYN   FELONY  11208
# 8        77         517518318       NaN   FELONY  11213
# 9        73         354783980       NaN   FELONY  11212

# %%
cleaning_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196853 entries, 0 to 196852
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Precinct          196853 non-null  int64
#  1   Complaint Number  196853 non-null  int64
#  2   Borough           196658 non-null  object
#  3   Category          196853 non-null  object
#  4   Zip               196853 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 7.5+ MB

# %%
# Drop rows with NaN values:
cleaning_df.dropna(inplace=True)

# %%
cleaning_df.head(10)
# Out:
#     Precinct  Complaint Number    Borough     Category    Zip
# 7         75         237202728   BROOKLYN       FELONY  11208
# 10        13         989134472  MANHATTAN       FELONY  10010
# 24         1         681808925  MANHATTAN       FELONY  10013
# 26        73         170101826   BROOKLYN  MISDEMEANOR  11212
# 27       103         817418587     QUEENS  MISDEMEANOR  11432
# 28       113         736247900     QUEENS  MISDEMEANOR  11434
# 29       109         722434037     QUEENS       FELONY  11354
# 30        73         240329077   BROOKLYN    VIOLATION  11212
# 31        40         807604372      BRONX  MISDEMEANOR  10454
# 32        61         766630185   BROOKLYN  MISDEMEANOR  11223

# %%
# Reset index after NaN rows were dropped:

cleaning_df.reset_index(drop=True, inplace=True)

# %%
cleaning_df.head()
# Out:
#    Precinct  Complaint Number    Borough     Category    Zip
# 0        75         237202728   BROOKLYN       FELONY  11208
# 1        13         989134472  MANHATTAN       FELONY  10010
# 2         1         681808925  MANHATTAN       FELONY  10013
# 3        73         170101826   BROOKLYN  MISDEMEANOR  11212
# 4       103         817418587     QUEENS  MISDEMEANOR  11432

# %%
# Save output:
cleaning_df.to_csv("Resources/crimes_by_zip.csv")

# %%
# Start new code here by zip code:

total_zip_crimes = cleaning_df.Zip.value_counts()
total_zip_crimes
zips = total_zip_crimes.index
zips
# Out:
# Int64Index([10457, 11208, 10454, 10452, 10473, 10466, 10013, 10467, 10451,
#             11212, 11103, 11216, 11236, 11354, 11226, 11428, 10065, 11372,
#             10027, 11434, 10001, 11432, 11230, 11237, 10035, 11373, 11385,
#             10301, 10010, 10461, 10029, 11213, 10019, 11211, 11224, 11417,
#             10030, 10465, 10033, 10459, 11418, 11221, 10314, 11223, 10014,
#             11225, 11365, 11232, 11214, 11691, 11101, 10003, 10463, 10306,
#             10025, 11205, 11201, 10031, 10032, 10002, 11204, 11210, 10011,
#             10024, 11217, 11222, 10022, 11375, 11693, 11361, 10307, 11231],
#            dtype='int64')

# %%
# Plot total crimes by Zip Code:
plt.figure(figsize = (14, 10))
x_axis=np.arange(len(zips))
plt.bar(x_axis, total_zip_crimes)
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, zips, fontsize = 10, rotation = 90)
plt.title("Total Crimes by NYC Zip Code", fontsize = 18)
plt.xlabel("NYC Zip Code", fontsize = 16)
plt.ylabel("Crimes per Zip Code", fontsize = 16)
plt.show()

# %%
# Read Cory's RetailerByPop file, for merging:

retailer_file = "Resources/RetailersByPop.csv"
retailer_df = pd.read_csv(retailer_file)
retailer_df.head()
# Out:
#        City Borough            Neighborhood    Zip  Lotto Retailers  \
# 0  New York   Bronx           Central Bronx  10453             56.0
# 1  New York   Bronx           Central Bronx  10457             65.0
# 2  New York   Bronx           Central Bronx  10460             42.0
# 3  New York   Bronx  Bronx Park and Fordham  10458             55.0
# 4  New York   Bronx  Bronx Park and Fordham  10467             55.0
#
#    Population  Retailer per 100k
# 0     79606.0          70.346456
# 1     74554.0          87.185128
# 2     59505.0          70.582304
# 3     83960.0          65.507384
# 4    103732.0          53.021247

# %%
# Merge the two dataframes:

raw_merge = pd.merge(cleaning_df, retailer_df, on="Zip", how = "left")
raw_merge.head()
# Out:
#    Precinct  Complaint Number  Borough_x     Category    Zip      City  \
# 0        75         237202728   BROOKLYN       FELONY  11208  New York
# 1        13         989134472  MANHATTAN       FELONY  10010  New York
# 2         1         681808925  MANHATTAN       FELONY  10013  New York
# 3        73         170101826   BROOKLYN  MISDEMEANOR  11212  New York
# 4       103         817418587     QUEENS  MISDEMEANOR  11432  New York
#
#    Borough_y                   Neighborhood  Lotto Retailers  Population  \
# 0   Brooklyn     East New York and New Lots             64.0     98660.0
# 1  Manhattan  Gramercy Park and Murray Hill             23.0     33730.0
# 2  Manhattan     Greenwich Village and Soho             65.0     28709.0
# 3   Brooklyn               Central Brooklyn             76.0     76527.0
# 4     Queens                        Jamaica             55.0     62053.0
#
#    Retailer per 100k
# 0          64.869248
# 1          68.188556
# 2         226.409837
# ...

# %%
# Drop unneeded columns:

merged_df = pd.DataFrame(raw_merge[["Precinct", "Borough_x", "Category", "Zip", "Lotto Retailers", "Population", "Retailer per 100k" ]])
merged_df.head(10)
# Out:
#    Precinct  Borough_x     Category    Zip  Lotto Retailers  Population  \
# 0        75   BROOKLYN       FELONY  11208             64.0     98660.0
# 1        13  MANHATTAN       FELONY  10010             23.0     33730.0
# 2         1  MANHATTAN       FELONY  10013             65.0     28709.0
# 3        73   BROOKLYN  MISDEMEANOR  11212             76.0     76527.0
# 4       103     QUEENS  MISDEMEANOR  11432             55.0     62053.0
# 5       113     QUEENS  MISDEMEANOR  11434             49.0     65791.0
# 6       109     QUEENS       FELONY  11354             57.0     55200.0
# 7        73   BROOKLYN    VIOLATION  11212             76.0     76527.0
# 8        40      BRONX  MISDEMEANOR  10454             33.0     38203.0
# 9        61   BROOKLYN  MISDEMEANOR  11223             70.0     81789.0
#
#    Retailer per 100k
# 0          64.869248
# 1          68.188556
# 2         226.409837
# 3          99.311354
# 4          88.633910
# 5          74.478272
# ...

# %%
len(merged_df)
# Out:
# 196658

# %%
# Count up violations, misdemeanors, and felonies per zip code in merged dataframe:

violations = pd.DataFrame(merged_df.Zip[merged_df.Category == 'VIOLATION'].value_counts().sort_index())
misdemeanors = pd.DataFrame(merged_df.Zip[merged_df.Category == 'MISDEMEANOR'].value_counts().sort_index())
felonies = pd.DataFrame(merged_df.Zip[merged_df.Category == 'FELONY'].value_counts().sort_index())

# %%
violations.head()
# Out:
#        Zip
# 10001  281
# 10002  271
# 10003  304
# 10010  374
# 10011  210

# %%
violations.reset_index(drop = False, inplace=True)
violations.head()
# Out:
#    index  Zip
# 0  10001  281
# 1  10002  271
# 2  10003  304
# 3  10010  374
# 4  10011  210

# %%
violations = violations.rename(columns = {"index": "Zip", "Zip": "Violations"})
violations.head()
# Out:
#      Zip  Violations
# 0  10001         281
# 1  10002         271
# 2  10003         304
# 3  10010         374
# 4  10011         210

# %%
# Merge violations per zip with retailers per zip and per 100k:

violation_merge = pd.merge(violations, retailer_df, on="Zip", how = "left")
violation_merge.head(10)
# Out:
#      Zip  Violations      City    Borough                   Neighborhood  \
# 0  10001         281  New York  Manhattan            Chelsea and Clinton
# 1  10002         271  New York  Manhattan                Lower East Side
# 2  10003         304  New York  Manhattan                Lower East Side
# 3  10010         374  New York  Manhattan  Gramercy Park and Murray Hill
# 4  10011         210  New York  Manhattan            Chelsea and Clinton
# 5  10013         472  New York  Manhattan     Greenwich Village and Soho
# 6  10014         229  New York  Manhattan     Greenwich Village and Soho
# 7  10019         328  New York  Manhattan            Chelsea and Clinton
# 8  10022         194  New York  Manhattan  Gramercy Park and Murray Hill
# 9  10024         215  New York  Manhattan                Upper West Side
#
#    Lotto Retailers  Population  Retailer per 100k
# 0             47.0     22924.0         205.025301
# 1             59.0     74993.0          78.674010
# ...

# %%
len(violation_merge)
# Out:
# 72

# %%
# Calculate violations per 100k:

violation_merge["Viol per 100k"] = (violation_merge["Violations"] / violation_merge["Population"] * 100000).round(2)
violation_merge.head()
# Out:
#      Zip  Violations      City    Borough                   Neighborhood  \
# 0  10001         281  New York  Manhattan            Chelsea and Clinton
# 1  10002         271  New York  Manhattan                Lower East Side
# 2  10003         304  New York  Manhattan                Lower East Side
# 3  10010         374  New York  Manhattan  Gramercy Park and Murray Hill
# 4  10011         210  New York  Manhattan            Chelsea and Clinton
#
#    Lotto Retailers  Population  Retailer per 100k  Viol per 100k
# 0             47.0     22924.0         205.025301        1225.79
# 1             59.0     74993.0          78.674010         361.37
# 2             38.0     54682.0          69.492703         555.94
# 3             23.0     33730.0          68.188556        1108.81
# 4             30.0     50472.0          59.438897         416.07

# %%
violations_per_zip = violation_merge["Violations"]
retailers_per_zip = violation_merge["Lotto Retailers"]

plt.figure(figsize = (10, 8))
x_values = retailers_per_zip
y_values = violations_per_zip
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50, 1200),fontsize=15,color="green")
plt.title("Correlation of violations versus retailers per zip code", fontsize = 18)
plt.xlabel('Retailers per Zip Code', fontsize = 18)
plt.ylabel('Violations', fontsize = 18)
print(f" The correlation coefficient between violations and lottery retailers is {round(st.pearsonr(retailers_per_zip, violations_per_zip)[0],2)}")
print(f" The r-squared is: {rvalue**2}")
plt.grid(True)
plt.savefig("Resources/Violation_correlation.png")
# Out:
#  The correlation coefficient between violations and lottery retailers is 0.35
#  The r-squared is: 0.12142316382191876

# %%
violations_per_100k = violation_merge["Viol per 100k"]
retailers_per_100k = violation_merge["Retailer per 100k"]

plt.figure(figsize = (10, 8))
x_values = retailers_per_100k
y_values = violations_per_100k
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50, 2500),fontsize=15,color="green")
plt.title("Lotto Retailers per 100k vs Violations per 100k by Zip Code", fontsize = 18)
plt.xlabel('Retailers per 100k', fontsize = 18)
plt.ylabel('Violations per 100k', fontsize = 18)
print(f" The correlation coefficient between violations and lottery retailers is {round(st.pearsonr(retailers_per_100k, violations_per_100k)[0],2)}")
print(f" The r-squared is: {rvalue**2}")
plt.grid(True)
plt.savefig("Resources/Violation_100k_correlation.png")
# Out:
#  The correlation coefficient between violations and lottery retailers is 0.37
#  The r-squared is: 0.13921961785569764

# %%
misdemeanors.head()
# Out:
#         Zip
# 10001  1714
# 10002   981
# 10003  1105
# 10010  1424
# 10011   794

# %%
misdemeanors.reset_index(drop = False, inplace=True)
misdemeanors.head()
# Out:
#    index   Zip
# 0  10001  1714
# 1  10002   981
# 2  10003  1105
# 3  10010  1424
# 4  10011   794

# %%
misdemeanors = misdemeanors.rename(columns = {"index": "Zip", "Zip": "Misdemeanors"})
misdemeanors.head()
# Out:
#      Zip  Misdemeanors
# 0  10001          1714
# 1  10002           981
# 2  10003          1105
# 3  10010          1424
# 4  10011           794

# %%
# Merge misdmeanors per zip with retailers per zip and per 100k:

misdemeanor_merge = pd.merge(misdemeanors, retailer_df, on="Zip", how = "left")
misdemeanor_merge.head(10)
# Out:
#      Zip  Misdemeanors      City    Borough                   Neighborhood  \
# 0  10001          1714  New York  Manhattan            Chelsea and Clinton
# 1  10002           981  New York  Manhattan                Lower East Side
# 2  10003          1105  New York  Manhattan                Lower East Side
# 3  10010          1424  New York  Manhattan  Gramercy Park and Murray Hill
# 4  10011           794  New York  Manhattan            Chelsea and Clinton
# 5  10013          2217  New York  Manhattan     Greenwich Village and Soho
# 6  10014          1203  New York  Manhattan     Greenwich Village and Soho
# 7  10019          1293  New York  Manhattan            Chelsea and Clinton
# 8  10022           775  New York  Manhattan  Gramercy Park and Murray Hill
# 9  10024           879  New York  Manhattan                Upper West Side
#
#    Lotto Retailers  Population  Retailer per 100k
# 0             47.0     22924.0         205.025301
# ...

# %%
len(misdemeanor_merge)
# Out:
# 72

# %%
# Calculate misdemeanors per 100k

misdemeanor_merge["Misd per 100k"] = (misdemeanor_merge["Misdemeanors"] / misdemeanor_merge["Population"] * 100000).round(2)
misdemeanor_merge.head()
# Out:
#      Zip  Misdemeanors      City    Borough                   Neighborhood  \
# 0  10001          1714  New York  Manhattan            Chelsea and Clinton
# 1  10002           981  New York  Manhattan                Lower East Side
# 2  10003          1105  New York  Manhattan                Lower East Side
# 3  10010          1424  New York  Manhattan  Gramercy Park and Murray Hill
# 4  10011           794  New York  Manhattan            Chelsea and Clinton
#
#    Lotto Retailers  Population  Retailer per 100k  Misd per 100k
# 0             47.0     22924.0         205.025301        7476.88
# 1             59.0     74993.0          78.674010        1308.12
# 2             38.0     54682.0          69.492703        2020.77
# 3             23.0     33730.0          68.188556        4221.76
# 4             30.0     50472.0          59.438897        1573.15

# %%
misdemeanors_per_zip = misdemeanor_merge["Misdemeanors"]
retailers_per_zip = misdemeanor_merge["Lotto Retailers"]

plt.figure(figsize = (10, 8))
x_values = retailers_per_zip
y_values = misdemeanors_per_zip
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50, 3500),fontsize=15,color="green")
plt.title("Correlation of misdemeanors versus retailers per zip code", fontsize = 18)
plt.xlabel('Retailers per Zip Code', fontsize = 18)
plt.ylabel('Misdemeanors', fontsize = 18)
print(f" The correlation coefficient between misdemeanors and lottery retailers is {round(st.pearsonr(retailers_per_zip, misdemeanors_per_zip)[0],2)}")
print(f" The r-squared is: {rvalue**2}")
plt.grid(True)
plt.savefig("Resources/Misdemeanor_correlation.png")
# Out:
#  The correlation coefficient between misdemeanors and lottery retailers is 0.35
#  The r-squared is: 0.11971938267947523

# %%
misdemeanors_per_100k = misdemeanor_merge["Misd per 100k"]
retailers_per_100k = misdemeanor_merge["Retailer per 100k"]

plt.figure(figsize = (10, 8))
x_values = retailers_per_100k
y_values = misdemeanors_per_100k
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50, 6000),fontsize=15,color="green")
plt.title("Lotto Retailers per 100k versus Misdemeanors per 100k", fontsize = 18)
plt.xlabel('Retailers per 100k', fontsize = 18)
plt.ylabel('Misdemeanors per 100k', fontsize = 18)
print(f" The correlation coefficient between misdemeanors and lottery retailers is {round(st.pearsonr(retailers_per_100k, misdemeanors_per_100k)[0],2)}")
print(f" The r-squared is: {rvalue**2}")
plt.grid(True)
plt.savefig("Resources/Misdemeanor_100k_correlation.png")
# Out:
#  The correlation coefficient between misdemeanors and lottery retailers is 0.53
#  The r-squared is: 0.2773675999552185

# %%
felonies.head()
# Out:
#         Zip
# 10001  1168
# 10002   547
# 10003   689
# 10010  1004
# 10011   599

# %%
felonies.reset_index(drop = False, inplace=True)
felonies.head()
# Out:
#    index   Zip
# 0  10001  1168
# 1  10002   547
# 2  10003   689
# 3  10010  1004
# 4  10011   599

# %%
felonies = felonies.rename(columns = {"index": "Zip", "Zip": "Felonies"})
felonies.head()
# Out:
#      Zip  Felonies
# 0  10001      1168
# 1  10002       547
# 2  10003       689
# 3  10010      1004
# 4  10011       599

# %%
# Merge felonies per zip with retailers per zip and by 100k:

felonies_merge = pd.merge(felonies, retailer_df, on="Zip", how = "left")
felonies_merge.head(10)
# Out:
#      Zip  Felonies      City    Borough                   Neighborhood  \
# 0  10001      1168  New York  Manhattan            Chelsea and Clinton
# 1  10002       547  New York  Manhattan                Lower East Side
# 2  10003       689  New York  Manhattan                Lower East Side
# 3  10010      1004  New York  Manhattan  Gramercy Park and Murray Hill
# 4  10011       599  New York  Manhattan            Chelsea and Clinton
# 5  10013      1343  New York  Manhattan     Greenwich Village and Soho
# 6  10014       867  New York  Manhattan     Greenwich Village and Soho
# 7  10019       974  New York  Manhattan            Chelsea and Clinton
# 8  10022       491  New York  Manhattan  Gramercy Park and Murray Hill
# 9  10024       449  New York  Manhattan                Upper West Side
#
#    Lotto Retailers  Population  Retailer per 100k
# 0             47.0     22924.0         205.025301
# 1             59.0     74993.0          78.674010
# ...

# %%
# Calculate felonies per 100k:

felonies_merge["Felonies per 100k"] = (felonies_merge["Felonies"] / felonies_merge["Population"] * 100000).round(2)
felonies_merge.head()
# Out:
#      Zip  Felonies      City    Borough                   Neighborhood  \
# 0  10001      1168  New York  Manhattan            Chelsea and Clinton
# 1  10002       547  New York  Manhattan                Lower East Side
# 2  10003       689  New York  Manhattan                Lower East Side
# 3  10010      1004  New York  Manhattan  Gramercy Park and Murray Hill
# 4  10011       599  New York  Manhattan            Chelsea and Clinton
#
#    Lotto Retailers  Population  Retailer per 100k  Felonies per 100k
# 0             47.0     22924.0         205.025301            5095.10
# 1             59.0     74993.0          78.674010             729.40
# 2             38.0     54682.0          69.492703            1260.01
# 3             23.0     33730.0          68.188556            2976.58
# 4             30.0     50472.0          59.438897            1186.80

# %%
felonies_per_zip = felonies_merge["Felonies"]
retailers_per_zip = felonies_merge["Lotto Retailers"]

plt.figure(figsize = (10, 8))
x_values = retailers_per_zip
y_values = felonies_per_zip
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50, 1500),fontsize=15,color="green")
plt.title("Correlation of felonies versus retailers per zip code", fontsize = 18)
plt.xlabel('Retailers per Zip Code', fontsize = 18)
plt.ylabel('Felonies', fontsize = 18)
print(f" The correlation coefficient between misdemeanors and lottery retailers is {round(st.pearsonr(retailers_per_zip, felonies_per_zip)[0],2)}")
print(f" The r-squared is: {rvalue**2}")
plt.grid(True)
plt.savefig("Resources/Felonies_correlation.png")
plt.show()
# Out:
#  The correlation coefficient between misdemeanors and lottery retailers is 0.37
#  The r-squared is: 0.1377621979623714

# %%
felonies_per_100k = felonies_merge["Felonies per 100k"]
retailers_per_100k = felonies_merge["Retailer per 100k"]

plt.figure(figsize = (10, 8))
x_values = retailers_per_100k
y_values = felonies_per_100k
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50, 1500),fontsize=15,color="green")
plt.title("Lotto Retailers per 100k vs Felonies per 100k", fontsize = 18)
plt.xlabel('Retailers per 100k', fontsize = 18)
plt.ylabel('Felonies per 100k', fontsize = 18)
print(f" The correlation coefficient between misdemeanors and lottery retailers is {round(st.pearsonr(retailers_per_100k, felonies_per_100k)[0],2)}")
print(f" The r-squared is: {rvalue**2}")
plt.grid(True)
plt.savefig("Resources/Felonies_100k_correlation.png")
plt.show()
# Out:
#  The correlation coefficient between misdemeanors and lottery retailers is 0.53
#  The r-squared is: 0.27826234091899
