# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/Boroughs.csv"

# Read Purchasing File and store into Pandas data frame
boroughs = pd.read_csv(file_to_load)

# set the index to ZIP Code to locate later on
boroughs.set_index("ZIP Code",inplace=True, drop =False)

# output
boroughs.head(10)
# Out:
#                                               City   Borough  \
# ZIP Code
# 10453, 10457, 10460                       New York     Bronx
# 10458, 10467, 10468                       New York     Bronx
# 10451, 10452, 10456                       New York     Bronx
# 10454, 10455, 10459, 10474                New York     Bronx
# 10463, 10471                              New York     Bronx
# 10466, 10469, 10470, 10475                New York     Bronx
# 10461, 10462, 10464, 10465, 10472, 10473  New York     Bronx
# 11212, 11213, 11216, 11233, 11238         New York  Brooklyn
# 11209, 11214, 11228                       New York  Brooklyn
# 11204, 11218, 11219, 11230                New York  Brooklyn
#
#                                                         Neighborhood  \
# ZIP Code
# 10453, 10457, 10460                                    Central Bronx
# 10458, 10467, 10468                           Bronx Park and Fordham
# 10451, 10452, 10456                       High Bridge and Morrisania
# 10454, 10455, 10459, 10474                Hunts Point and Mott Haven
# 10463, 10471                               Kingsbridge and Riverdale
# 10466, 10469, 10470, 10475                           Northeast Bronx
# 10461, 10462, 10464, 10465, 10472, 10473             Southeast Bronx
# 11212, 11213, 11216, 11233, 11238                   Central Brooklyn
# 11209, 11214, 11228                               Southwest Brooklyn
# 11204, 11218, 11219, 11230                              Borough Park
#
#                                                                           ZIP Code
# ZIP Code
# 10453, 10457, 10460                                            10453, 10457, 10460
# 10458, 10467, 10468                                            10458, 10467, 10468
# 10451, 10452, 10456                                            10451, 10452, 10456
# 10454, 10455, 10459, 10474                              10454, 10455, 10459, 10474
# 10463, 10471                                                          10463, 10471
# 10466, 10469, 10470, 10475                              10466, 10469, 10470, 10475
# 10461, 10462, 10464, 10465, 10472, 10473  10461, 10462, 10464, 10465, 10472, 10473
# 11212, 11213, 11216, 11233, 11238                11212, 11213, 11216, 11233, 11238
# 11209, 11214, 11228                                            11209, 11214, 11228
# 11204, 11218, 11219, 11230                              11204, 11218, 11219, 11230

# %%
# set the lists to blank before appending
zip_list = []
neighborhood_list = []
borough_list = []
city_list = []

# loop through the cells in the data frame to pull out the individual zips
for x in boroughs["ZIP Code"]:
    
    # split out the individual zip codes
    zips = x.split(r", ")
    
    # loop through the individual zips that we just pulled out to expand df on ZIP Codes
    for item in zips:
        # appends to lists per category
        zip_list.append(item)
        neighborhood_list.append(boroughs.loc[x,"Neighborhood"])
        borough_list.append(boroughs.loc[x,"Borough"])
        city_list.append(boroughs.loc[x,"City"])

# create a new dataframe where every ZIP Code has it's own row     
NYC_zips = pd.DataFrame(
                        {"City":city_list,
                         "Borough":borough_list,
                         "Neighborhood":neighborhood_list,
                         "ZIP Code":zip_list
                        })
# output
NYC_zips
# Out:
#          City        Borough              Neighborhood ZIP Code
# 0    New York          Bronx             Central Bronx    10453
# 1    New York          Bronx             Central Bronx    10457
# 2    New York          Bronx             Central Bronx    10460
# 3    New York          Bronx    Bronx Park and Fordham    10458
# 4    New York          Bronx    Bronx Park and Fordham    10467
# ..        ...            ...                       ...      ...
# 173  New York  Staten Island               South Shore    10312
# 174  New York  Staten Island  Stapleton and St. George    10301
# 175  New York  Staten Island  Stapleton and St. George    10304
# 176  New York  Staten Island  Stapleton and St. George    10305
# 177  New York  Staten Island                Mid-Island    10314
#
# [178 rows x 4 columns]
